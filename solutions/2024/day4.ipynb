# %% [markdown]
# ## --- Day 4: Ceres Search ---
# "Looks like the Chief's not here. Next!" One of The Historians pulls out a device and pushes the only button on it. After a brief flash, you recognize the interior of the Ceres monitoring station!
#
# As the search for the Chief continues, a small Elf who lives on the station tugs on your shirt; she'd like to know if you could help her with her **word search** (your puzzle input). She only has to find one word: `XMAS`.
#
# This word search allows words to be horizontal, vertical, diagonal, written backwards, or even overlapping other words. It's a little unusual, though, as you don't merely need to find one instance of `XMAS` - you need to find **all of them**. Here are a few ways `XMAS` might appear, where irrelevant characters have been replaced with `.`:
# ```shell
# ..X...
# .SAMX.
# .A..A.
# XMAS.S
# .X....
#
# ```
#
# The actual word search will be full of letters instead. For example:
#
# ```shell
# MMMSXXMASM
# MSAMXMSMSA
# AMXSXMAAMM
# MSAMASMSMX
# XMASAMXAMM
# XXAMMXXAMA
# SMSMSASXSS
# SAXAMASAAA
# MAMMMXMMMM
# MXMXAXMASX
#
# ```
#
# In this word search, `XMAS` occurs a total of `18` times; here's the same word search again, but where letters not involved in any `XMAS` have been replaced with `.`:
#
# ```shell
# ....XXMAS.
# .SAMXMS...
# ...S..A...
# ..A.A.MS.X
# XMASAMX.MM
# X.....XA.A
# S.S.S.S.SS
# .A.A.A.A.A
# ..M.M.M.MM
# .X.X.XMASX
#
# ```
#
# Take a look at the little Elf's word search. **How many times does `XMAS` appear?**

# %%
import numpy as np

raw = '''
MMMSXXMASM
MSAMXMSMSA
AMXSXMAAMM
MSAMASMSMX
XMASAMXAMM
XXAMMXXAMA
SMSMSASXSS
SAXAMASAAA
MAMMMXMMMM
MXMXAXMASX
'''

data = np.array([list(line.strip()) for line in raw.strip().split('\n')])

def search(array, word, x, y):
    '''searches for word in 2d array horizontally, vertically, and diagonally starting at x, y.
    replaces characters of found words to lowercase, and returns number of instances found.
    '''
    ys, xs = array.shape
    count = 0
    n = len(word)
    word = word.lower()
    a2s = lambda a: ''.join(a).lower()
    s2a = lambda s: np.array(list(s))
    
    # hlr
    if x <= xs-n and a2s(array[y, x:x+n]) == word:
        array[y, x:x+n] = s2a(word)
        count += 1
        
    # hrl
    if x >= n-1 and a2s(array[y, x-n+1:x+1][::-1]) == word:
        array[y, x-n+1:x+1][::-1] = s2a(word)
        count += 1
        
    # vud
    if y <= ys-n and a2s(array[y:y+n, x]) == word:
        array[y:y+n, x] = s2a(word)
        count += 1
        
    # vdu
    if y >= n-1 and a2s(array[y-n+1:y+1, x][::-1]) == word:
        array[y-n+1:y+1, x][::-1] = s2a(word)
        count += 1
        
    # diagonal
    i = np.diag_indices(n)
    
    # dlrud
    j = tuple(i + np.array([y, x])[:, None])
    if x <= xs-n and y <= ys-n and a2s(array[j]) == word:
        array[j] = s2a(word)
        count += 1
        
    # drldu
    j = tuple((i + np.array([y-n+1, x-n+1])[:, None]))
    if x >= n-1 and y >= n-1 and a2s(array[j][::-1]) == word:
        array[j] = s2a(reversed(word))
        count += 1
        
    i = (i[0][::-1], i[1])
    
    # dlrdu
    j = tuple((i + np.array([y-n+1, x])[:, None]))
    if x <= xs-n and y >= n-1 and a2s(array[j]) == word:
        array[j] = s2a(word)
        count += 1
        
    # drldu
    j = tuple((i + np.array([y, x-n+1])[:, None]))
    if x >= n-1 and y <= ys-n and a2s(array[j][::-1]) == word:
        array[j] = s2a(reversed(word))
        count += 1
        
    return count
        
total = 0 
for y in range(data.shape[0]):
    for x in range(data.shape[1]):
        total += search(data, 'xmas', x, y)
        
total
# Out:
# 18

# %%
with open('day4.input') as f:
    data = np.array([list(line.strip()) for line in f.read().strip().split('\n')])
    
total = 0
for y in range(data.shape[0]):
    for x in range(data.shape[1]):
        total += search(data, 'xmas', x, y)
        
for y in range(data.shape[0]):
    for x in range(data.shape[1]):
        if ord('A') <= ord(data[y, x]) <= ord('Z'):
            data[y, x] = '.'
            
print(total)
print('\n'.join(''.join(line) for line in data))
# Out:
# 2583
# ............xmas..x.....samxs................x.x..........samx.s.....samxmas.x......x....xmas...xmas....xmas.......s..s........samx...s.s...
# ...x.......sm..s.sms.......a.....samx.s..xmas.msm.....s..s..s...a..........xmas..samx.......s..........mxsa...xmas..asamx...........saaax...
# ...sm......aasa...a.a.....m..........m.a.samx..a.a.xx.aa.a.xa...sm....x.sx.a...a.xa......xmas.........amamxs..m..samxmm.mm.......x.am.m.m...
# ..a..a.x..smsma...sm.m...x.......s.s..a.m......ms.s.msm.mm.mm..a..xsamx.ams.....msm.s.....m.....xmasxsamxma...a.....m.x.a.a...s.samx.xxmas..
# .m..s.s.ma.xx.sm....x.xsm.s.......a....sxx.....xaa..aax..x.axxmas..mam..ma.......x.a....sxx......s.m.sxsamx.s.s..s..a...ss.s..aa.x.ax...sa..
# xs..a...ma.x..xax.....aa.a.x.....m.m....m......mm.mmsms.s..s.x.....sa...xs......m.m.s..asamxs.sx..a...asx..x.a.xa.x.s.....a.x.msm...smx..m..
# ..a.m..xs.s.m.mmm....msmmssm....x...x...a......axxxxaa...a.........s.s......s..a.x.a..m...axmas.ms.m.m.s.s..m.mmsm.......s.m.xxaa.....am.x..
# ..xmxxmas....aa.ax..x..x.aaa.samxm.msamxs......s.smsmsm...m......x.sa..xmasa..s.m.m..x....samxm..aa.x.a...a..axxaa.....x..a.xssm.ms....sa...
# .xm.x.mxmasx.ss.ss.x.....mms..asx.aa..............aaaa.x...x....m...am...am....a.x....m.ss.xx.xx..sm.m.....ms.ss.sms..mm.s.ma..x.ax......s..
# .ma..xm..xmsamxa..m...s..xxmasammsmsamx....x.......ms.s.m......a.....mx.mx...xs........a.a...m.m....x.......x.....ax.a.a.samx...m.......x...
# .as..a..ma.xx.mx.a.....a..x..ma.ax.xmas.s...m.....x.x..a.a...sss......xxx.mxm.........m.sm.xa.a.a..........x.....m.ms.ssxsxmx..xsamx.....m..
# xs..sxmas...mxmas.......msamxs..s.m....a.....a.....m....m.s.aaa........m..samx.......x..xxssms.s.s........s.m...x...xaa.am.mx.m...s.m.....a.
# xma.x.s.....aas..........x..a....a.xsamx......s..x..a....x.mmm.m......a...s.samx.......m..a.aa.....s.....a...a.samx.m.mm.xa.aa....x..a..xs.s
# .mam........s..a......x......s..s.m.mxsx..s.....m.m..s....xxxsamx....s..samx..s.xmas..a...mm..s...xmas.sm.....s..m.xa.x..smsss.s.s.m.ss.ams.
# ..asx.....s...ssm....mm...x.a....a...amax..a...a...a.....m.............xmas.....m....s.sx.x..........max........a.s.samx..aaa.a.a..samxm..a.
# .s.s.m.....ax.aaax..a.a....m....samxmasamm..m.s.....s...a...s.s.........samx....a......masx.....s....mxm.......s.s.a.......msm.m.m.m.sx.s.ms
# ..a.x.a....smm..mmms.ss...xmas...xmas...sxax.x...x.samxs.x.a..a...s..x....xmas.ss.....a.am.....a.samx...x.s......a..m....samx.x...x..samxaxa
# .mxmas.s..a.xxa..xxa.a.....s.s....s.s.....ms....mx........m...m..a....msamx...a.a...ss.ma.x...m...s.xmas...a.....m...x....................mm
# x.as.samxm..xmas..mmsm....xmas...aa..a...a..x.sam........x.a..x.m..x.x.aa.xmas.mmm..a.xs.....x...a.xsm......m.x..x.s.s.samx.......x...s.s..x
# ms.a.m..x.....a....aax..xmas.m..m.m..xm.sxxm..sa..x......xmas..x.s..m.smsm.samx.x.xmm.......x...mxma..a.x....xmsamxa.aa.s..s......m...ax.a.x
# a..mx..s.......s....ss...s...sxx..x.m.sxm.am..s.m..ms......x....a..a.a.x.xx..m.s..x.xsamx...m..xmam.s..s.m..m.ax...m.m..a.a.a..s..axsamx..m.
# sssx.sa...........x....xaxx...asxs.a.ama.s..a....x..aa.s...m...m..s.m.s.m...a..sa.....a....xa..asx.asamx..aa..sm...xxx..mm...m.a..s.max..a.x
# .aa.am...........m....smmm.m...maas.masx.....s....x.xsm.a..a..x.s..xs.samxss....am.....m...ms.s..m.xs.mx..ss...a.....s..x....sxmsxmasa..ss..
# ..mmx...s.samx..a..samxa.a..a.amxm.xsamx.....a.....m..ax.m.sx...a.samxs....a.....mx..s..x..a.....a..m..xm......sm...a.samx..a..x.as...s.aa..
# x.xxx....axmasms......s.mss.ssx..xx..a.......m....a.as.m.sxmam..m.m...m...samx....x.a.a..s.s.....s...a...a....x..x.mx.x....m......mas..m..m.
# .m......m.ms...ax.....samx.axmas..m.samx.....x...sx.xsa.xsamxmasxxs....as....x.....m...m..a.......s...s...s..m...mxm.s.m..x.....samxmax...xx
# ..a....xsamxa..msamxs...m.m.......a..............m...m.m.samx.xs.a......sa...m....x.....xm.mx....a......x..xa....aa...a.a..s..s......xm..m..
# xmas.........ma...samxsamxmas.....s......s.s....a...x.axx.asxm.sm......a..m..a.x........xsamxs..m...s..ms.msm.s..s.....m.sa..a.....sm..xa...
# ..x....x.samxsx..xmasas........s..a.....a.a.a..s...m.smsssxmasax......m....x.sm...........a.a.ax...a..a..a.x.a...x..x.x.xm..ms.....aa..s....
# ..m...m...x...x..x...as.........a.ms.samxm...m....a..a.axmasxmx......xmas.s..a.....x..xmas.ms.sm..m..ss.s.m.m.s.ms..mms.x..xa.....sm.m......
# ..a..a.....m..m.....s.m...s.....xmx.a.x.xs....x..ssssmm..m.mxmxms....xmas..as......m.m.m..x.xa.axx.....as..x.a.a.a..a..a.xmm..samx.xxxx.....
# ..s.s.x.....a.a......a.x.a.......mx..m..xa.x......a..x...sama..aa.......x...ma.s...aas.sas..s.m.mm.....am.....s.mm.ss...max..xa..msmm.s...s.
# ......m....s.ss.......m.m..s..s...a...x..m..m....mm.x.x.asas..m..s......m....xm.a..s..a.as.a...x.xa...m..xsamx...x.....asx.m.mm.saaa...axa..
# ......a.....a..........xsaax..xa.x.s..ms.xa..ax.x.x.m..mxsam.x......s...a.x..x.x.m.....m.mm.x...s..s.x...............xs.m...aaxamsss...smm..
# sss.s.ss.....m.........amms.m..mm.x...aaxmas..sm.sm.axx.ama.x....x...a..s.mm..m...x...x.xxxm...a...samx....s........m..axmas.smx..x....xaxa.
# .aaaaaaxmas...x.......m.xa...a.aax.m..sm...sa.a.a.a.sms.xsam....m.....m...axa..a..s..ms...a..sm....x.x....a..s.....a..ssm...axa.xsamxmas.mxs
# ..mmmm.........s.....x..s.s...s..s..aa.x..a.xmmm.ss..a.....sx..a.......x..s.ms..s..aaaa..s..ax....sm.m...m....a.x.s...a.axxmasxm..xmam.samxa
# .xxxxx...x....a..xs.m....a......ax..ms..sm..m.x.....ms.......xsx....x.xx..xs.a...x.sm.msamxm.mxmasaa.a..x......mxmas..msamxm.mamxma.xsa.a..m
# ..m....x..m..m..m..a....samx...mm..x.a..xaxmas.s...xsx........m.m...mmm..ma..mssm..x.xxm..xx.a..x.ms.s..sss....xx.a...x...xmas.mas.msm.s.m.x
# .a...ssm...ax..a..s.m..xmasx..xa..m..m.msamxs.a....xmas........a.a..aaa.am...x.a.s..x.x...mmms.m..x.a..aaaa....m.m.s.....s.sasas.sa..aa..xx.
# s.x.a..a....s.s....a.x....m.s.sxmas..xa....x.m.....a.am.........s.sss.ssx.x..xsm..a..m....a.aaa......mmmm.mm...ax.a.......amasa..s.m.mms.m..
# ...m..xsm...ax......m......xa..asa...ss..ss.xsamx.sssssxs....xmasa.aaa...mx...mx...m..a...s.sss.s...xxxx..x.x..s.m.s......xm.m.m....x..x.a..
# ..xsam...xs.m.s......xsamxxsm.x.m....aa.aa...m....aaaa.asamx.xmas.mmm...am.x...a....x..s.x.a.xmasa.s.ms.sm........asamx..m..x.x.x........s.s
# ....as.....axas.....x.xmasamxm.xxx..m.mmm....samx.mmmmm...m.mxmasx.xxs.sa..sms..samxs.....m.m.sam.m.a.a.aa..x....m.s.m..a.....m............a
# ...s.m.s..s.ma......m.ms.m.xa..sm.sx..xx.......s..xx.x.xsa.a.am.s.samxas..ax.a...a.a.....xmas.ma.x.x.mms..m..m..x.....xsamx...axs..........m
# ....x.x.ax.xmx......a.aax..sms.aa.a...mm....s.....s.m.m.sasxsxs......mxm.m.m.ms...m.s.....s.sxs.m...s.x....x..a.......m.......s.ma.........x
# .x...msmmm.x..m..s..smsm.....a.msmm..a.a.x...a.xmasxmas.sxm.ax...s.sx..mx..a.xx.xx.x.a........ma.x...a.xx...xmas......a.....x..a.am......xmx
# ..m...aaaaxx...a..a.x..x......sx..x.s..s..m.samxmas.s.s..amxmm...samx...a..s...m..samxm....xmasam....xm.mm.........x.xs.s.ss.m..m.sx...xmasm
# s..a..ssms.m....ss.m.........a..xx....x..s.a.a.x.x.asamxs.maxa...m.m.....sxmasa.a...samx..s....asxs.ma.x.aa...s.s.smsm..aaaa..a..xsxs..asa.a
# a...s....x.a....xmasx.xmas..m...m.xmas.ma...s..ms.m.m.....sxss..x.a.x...x....s...s...a...a....s..x.asamx..sss..a.a.a.a.xmm.xm..ss.ma.asamx.s
# m.......m..s....ms.m..xmas.x.x.aa..m...ma.xxmasaa..a.x..x........s.xmas..m.samx.....s.m.m.samx...ms.m.sms..a....m.ms.smxx..m.x.a.a..m.mx...a
# x......a........a.x.x..m..a..ms.s..xaxxmasm.xmasmxmas.x.xm................a.a........a.x.xs......a...x.aa.m..ssx.x.x.a.x.x.a..m.s.m..x.xmasm
# ......samx......sm.m....a..m.a....m.ms..a.a...m.x......m..as.....s.xmas....sxm........m.m.ma...s.s....ssmx..a..a.sm.s.s..sms.x.a...x..m....x
# x..............sa.a......ss.xs...a.aa.xm.ss...xx.m.s..a.axxsa..samx....a...smsx.samx..sx.a.am...aa...a..xxmm.ss.maa.aa....aa...sss.xmas....m
# mm.....x...s...sas.x......ax..a.s.sm.mx..a.a.xm...a..s.smsm..m.ma.......m...a.ax.xx....a..s.sx.m.m..m.xsamxa.xaasx.mm...sm.ms.a..a..sa.....a
# a.a....m....a.a..mm.......mmm..m..x.am.m.m..mas..m.s...aa.a..xx..m..x.x..x.msmsmmsms..s.m...x.x.xxxx...m.msms.mmm..xx.sax..xxm...m..x.s...xs
# ss.s...a.xmasm...ax.......xxxa..x..samx.axmasx.ax.a..ssm.ms.m....xx..m.m..x...xaxaaa...a.x...mmmmm.m....a.a.a.xaxx....ma..smx....x...m...m..
# ..as...s....x.x.s..ms....msm.ss....s.smmmssxmas.mmx.a..x..xa.xsamxs.x.a.am.xmasxmmsm....ms..a.aaaxaaa..s.sm..s.ss....xs.maaa......m...a.a...
# ...ma.a..........a..aa..aasamxa.......aaa...x...xxam.s....s...ma.a...m.sas..m...mx.x..s..xas..ssmsss.s....x...aaaa.x.a.amxms.s.xs..as..s...s
# ....xmas..........m.ssmsm..s...m....s.sm.s.m.m.m.mxsa...x.x...sam.....as.....a.x.am...aa..mms..aaa.ax.....xsamxm.mm.m..xm.x.aa.am...sa..a..a
# s...x.x.........samx.a.x....xmasx..x.a.ax.a...a..aam.sx.m.msamxxsx.....s......s.masx..mxmasax.sm.m..mm...m..x..xx.xxsamx.x.m.mm..a..s.m..m.m
# a....ssssss...........ms...s........m.m.msxmas.s.sxs.m..a.a...........xmasamx...sam.s.x..xmxsamx.xx..xa.a..m.m.m...xmas...x..x.xmasa...x..xx
# m...a.aaaa...s...s....xxa.a.....samx.a.x.xa.a.axa...a...s.s....x.......mxmas.....asa....sxm.m.m....s...s..a...a.......ma..m...m...m.....m..s
# xsamx.mmm...a.a.ax....m..m............s.m.xmasmmx.xs.....a.xmas.m.......a.x.....s.m..x.a.asa.a....a......s.s.s.s.ss..x.xm.a....a.x...xmasaa.
# ..x..xxxx..m...m.sm...a.x.xmas.........a..xxxax.xm........m.x....a.....s.s......sxsx..m.s..as.s.sm...xx.a.x.a.as.aa...m..xs.....s..s.....ms.
# x..xssm...xsssxsxa.a..s...............s...mmsm..a.a..samxa.xxmas..sss...a.a....am..amxsamx..m...xaxs..mm.sm..ma.m..m...a......xa.xx.a...x...
# m.m..a.....aa.a..m..s.......x.....x..xs..a.aa.as...samx.s.....a...axmas..msm..ma.x..mam.s.ms.x....m.a.xaa.a.xmxx....xxmas....mmsmm.s.m...m..
# aa..smm....mmm.m.x..........sm..samx.xmas.ms...s.x......a...xmas.m..m.ma..xaxxssm....xsa.x.ax.x.x.ax.m.msss.x...ms.mxmas....ax.aa.a..sxmasa.
# s....x.x..sxx...x.......s....aa.x.a....amx.......ms.x...m.s.....xs...a.xm...m..a........sm.msm.m..sm..xaxa....x.aaa.samxx..s.sss.m...xasamxs
# .........a......m..xmasa......ms.ms..s..sx.......a..m...x..a..samxa...s..x.asxsm.......x.aaxa.a..a.a..msmm.s.m.m.ss.xax..m..aa..x.xsamxm....
# ........m.......a.....m.s......x..a...a.a.mxss..msx.axmas..xm.ax...m..x...s.a..xs......mmsssss.sm..smx.xa.asamx.ax...mm...a..msamxa..a.mx...
# .......x....s...s....x.a......m..s.s...mmxma.aax..m.s.m.s.m..xmas..sx.m.....m..a......sa.a...a.x.....x...m.sam.m..m...ax.x.sxxx..m...sxmas..
# ......x......a......m.m......a....a.xs..xam.s.mm..a.a..a.ax..ax.....a.a..s..xsm......a.sm.sx..m.....m.....x..mxmas.a..ss..m.amx.xax..mxmas..
# .....s.m......m...samx...xmas......maxmas..asamxxss.m..ss.m.sxmas....ms...a.axmasamxmasx...m...x...a......m...xmas..sa.....a.mam.s.mas.s....
# .....xa.a......x..s.m.............amx..x....s.m...axxs..a.axmasamx..x.x....m....s..x..samx.a.....ss.......a.s....x..m..samx.s.xsa..sa.a.a...
# ..xmasmm.s.s.s.....a.x...s.......sx..mmms......x...m.a...ms.......xm.xxx..x.x..a........ss.s..x.a...s...s.s.a....m.xs......m..xmas...s.msm..
# ...m...ax...a.a...s.m.....a......s...aaaa..s...s...axm.s..x.samx..am.mm.......m........a.xa..m.m.....a.a.a..m....a.a......xmasx..m......xax.
# ....axmasm...m.m...a.......m..x.axmas.msm...a...a..s.x.a.....a...s..aa.......x.......sm.m..ma.xsa.x..sm.msamx....sm...s......s.m..x......mm.
# .....s....a...x.x.sxxmas....xsamx...xx..x....m...m.....ms.ss..m....sss.........xxmasaxmas..sx.a..s.m.xax........xx...ax..x......a.......s.ax
# .x.xsamx..ss..m.m.ms....xmasamx.am.m..m......sxs..x....x.a..ax.x..xaa...........m..mm.s..axa.m..xmasa.sm...s...smm.smm..m........samx...a..s
# ..mxmasx.a....a.aaax..........s..sa....a..xmasa.a...s...m.m..mm....ms.......samxaaxa......mmxs.s..a.asaax...a.a.a.axa..a......xmas.....xm...
# .a.a..m.m.....s.smsm...........a.s.s....samx.x.m.m...a.x...x.axa..xxa...s..a..sxs.s......x.xa.aa.m.s.mm.m....ms.sm.s..samx...x.s...s.sm.xs..
# sx..s..xmas.....xa.a............mx....x...msmm..x.x...m.....sssmss.sms.a..mx...ama....xmasm..samx.xmasxs.xs.x.xaxx......m...m...a...aa..a..x
# .m........s.s.s.ms.s............mx...mx..aaa.a...m.m...x......a.a..axam..xm...mxmamxmas...aaa..xx....m.a.as.samxm......ax..a.....m.msm.m.sm.
# .a....x...s..aax..aa.......s...am...am..sms..s.s..asa....x....mm.s.m.xs..am..xm..xsx.x....sms.........xmma.xs.samxs...ss.ms....s..x..ax.aa..
# .s...m..sa.a..m....m......x.a.sa...sa...x.....a...asxsx.samx..x....xmas.s..a.amsmma.m.m...xax.....s..m.xmasm.as.samx..aa..a..samx.samxmms...
# s..sa..am.samxxx...xx....s.m.ms.s..s.xmas....m.m.m.m.m.ax..a............samxs..a.am..a.a....m......aa..x.x.a..m.m.s.mm..m..s.m.x......xxxa.x
# a.as..mx..samx..ms......a...a.xaxx..x.......x...x.a.a.mm...xs.....samx...xmas.smssx...sxs....x..sxssms....ms...x....xa...x..x...m.s..m..m.ms
# mm...xsmx........aa....m.....smsm..s.m........s..s.s.xa....m...........xmasxmasxmas..ax.mx..mx..maaaax.....a....x..xmas..........a..a...aaax
# x......a.m..xmas..sm..x......xaaa.xa..axmas....a..aaxsx...xa.......s...as......a..m.m.m.xamam..a..mm......s.sx...m..............m.ss....sm..
# ......ssm.as........xs.......ms.sm.m.s.sx..xmas.mm.m.m.s.m.s......a.a.s.......s.m..x..a.m.sa..s...xx.....a..m....samx..xx......x.....x..xa.x
# ...s...a.x.samx.....xmas....x..aa..x..a..ms.s...xxaxa.a.a........m...m...s.....a.xx...s.a.sxs.s..s.ss...m..a...s..as.m.m.......xmas.s.m.samx
# xmasamx.m....m.ss.s.m..ma..sss.sms.s...m..aaa...ms.smmss........x...x.x.a.......mms.samxs.ma...a.aaaa..x..s.s.xa...m..aa.....xmasa...a.a.a.x
# .m...xmasx..a.x.aa.sa...xm..aaaaaxa.....x..sm..a..aaxa...x..........msamx.......ax.ama...am.....mmmmmm....sa...m...sxs.s....x.....s...m.s...
# xxmas.xa.a.samxsmm.as....xx.mmmm.mx..x....a.xxs..m.mm.s.s.m.s....s..a.x........s...xmxmasx.......x..x.x..am....xa...a.a.a..s.m.........x....
# ..s...m.samx..axx.xm......m.xxxxx.m.m....ms.....x..x...a...a....aa..s................x.x..m...........samx..s.m.mssmsm...m.a.sasamx.........
# ...a.xa....x.mssmm.x.xmas..a..s...aa....x..a.....xs...m.m.m.s..m.m.........xmas.....m.s.mx.a...x.samx..x...asamxaax.xax...xm..as.s..........
# ....mxs.ss..xxa.aa.......a..sa....sx.....x..m.....ma.x...xx.a.x..x...........x.a...ax..a.am.s.m......x....m.s.mmm.sm.mmss..x.m.ma...........
# ....mxa.axmasmms..s.......mxm.......m...m....x.....am..smm..m....s....s.....m...m.sm.s..m.sasa.s.s..m....x...axx..a.a.ax.a..x..mxmas..x.x...
# ...a..mmmsamxax..a.a..xsamxxm.ss.....a.a...sm......asx.aa...xs....ax...a.x.a....xxaa.a.s.xmasa.aa.xaxmas....samx.s.samx...msamx...x..m.m....
# ..s...x.x....sm.mx.xmasm.m...aaaax....s....aa..s..s...ss.m.sa..sxsmms.ssm.s..samxs..mm.aa.....mm.msm.....samx..x....x.ms..ax..s.....a.a.....
# .......m.ss....xm....x..axmasms.mm...xmas.s..ma...........xma..maa.ax.aa.xs..samx.a..x.m.m...sxx..x.a.................aaam....a....s.s.....x
# x..x....a.aa...a.......s.s..xx.a.xx..........mxs.....x.samx..ma.smms.ms.ma...sxmx..m...x..x...am.s.m.s.......x........smxm...xmas..xaa...s.m
# mxmas....s.mmsss...........mm.s..mm.samx....xmasamxs.m.xmas..sx..xx.x...mx....m.xm..x.x.m......ma.a.a...samx.m......samx..x..xxx.xmm.m.xax.a
# aa........a.xxa..s...s....aa....a.sas.s.s.s.am...ma..a.................x....xmas.mam.m.x.a......xs.m.ss....x.a........m....x..m.max..x.mmm.s
# s..........m.m.m.sa.x.ax.ss....s...asa.a.a.sxmasam..xs......sx..........m.s..ms.s.asa...m.s..s...sx.x.a.samx.s.s.....a...s..m..asa..s.xa.a.a
# ........xsamxmasx.am...mm.a...x.....m.m.m..m...sx...xm....s..am.s.....s..a.a..aaas.s.xmasa.a.a..am.m..m..am.xmasx...s...a..s.as.s.sas.ss.s.m
# ........ms.....x.mamxmasxa.m..m...samx.x.xa.....a..m.samxa.asxma.a.xmas...s.m.msm.........s.mm.ma.asamx.sa...m..msamxx.m...a..s...mas......x
# ..xmas..a.....xmasa.xmas..s.x.a..a......mss...x.xma.x..sm...mamxsamxmas......xx.x....xmas..a.xxsss...sm.s...x...a..samx.x..m..s..xmas.......
# x.......s......a..xs.ma.......s.mx.x...x.a.a..msmsxmsamxa..a.xmasamxmas.samx....xmas...xmas.m.m.a...x.a.........s....a..mx.x...a.xma........
# m........s.....samx.x..s....s..xmxmxm.m.m.s.m.aaa.a....ssss.s.mxs.m.m.s....xsamx.m..a........xa.m.s.m.s...........s.ss..a.m.m...mxmas.xmas..
# a....s...a....xmas.........xa..amama.a...a...xsmss...s..aa.a.x.....x.a......m.samxa..m......m.s.xa..a..xmas..x.....a....s..a.a.a.xsa........
# s...a.a..m...s.s....x.......m.s.sa.as.s...s...mx..a...a..mm..m......m.s...x..a...s.sx.x....a..axmas.samx.....xm.s.m.mx.a.a..s.ss..max.......
# ...m...m.x....a..s...m....x.xaxasxs.s.samx.x...a...m.s.m.xxx.a.......a.....m..s..samx.....s...mx........m.s.m.samx...xmas.m.a.a..x..m.s.s...
# x.x.....x....m.ma.a...a....m.ms.m...samxm..m...xsamxx.a.xmxmasx.....sss.....a.....am..........x..........a.a.xmas.m..x.a..xxmm......ax.a.a..
# .m.s.....m..x..mx..m...s....aaaa.x....masx.a....m.m.m.sm.a.....m....a..a.s...s...s..x...................m.s..xs.m..a..m.s..mx.x.x...s...m.m.
# ..a.......a...x.....x......smsss...xmasa...ss.s..as..a..xsx....sa..mm...m.a..x.....x.m.....s.s.s.......x....xa...xxss..a....am.m.........x.x
# .m.s...s...s.s..s..s.......x...a...ms.m....axx.asas.m.s..m..xmas.sx.x....x.msms.sssm..a.x...aaa.............mms....ma...s..sasa........samx.
# x.a.....a.....aa....as....mx..xm...a.x....m.mm..m..x..x.a....m.....mss..s...xaa.aa.a...sm...sm.s...........x..a.....am..a.as.s.s............
# .m..s....m....mmx.x..ma.xa.m.m.x.s.s.....x.a..ax.xmas.ms...xx.s..sa.xa.a....msmmms.sms..a..axxx.as............mss..s.sx.mm..asamxs.s.s.s...s
# x.aa..x...x..x.mx..mx.xms.xaa.x...a.a.....s....s......aa...m..a.as.m.mm....x..xxxa.a.xa.s.m.m...am............x..aaaxx..x..m.mas..a.a.a.a.a.
# .mms.mm.....xmas....amamxm.s.m...m.m.m.ss......s.....msm...a..mm..a..xax.s.sm.ss.msm...m.x.a...m..x.........x....mmm..m.m.x.xsamxm.m.m.m.m..
# .xa.a.a......s......asa.a...a.x.xmasx.xaa.......a...x..x.s.ss.x..s.....s..aa.aa.axaxmas.x.s.s.x.............ms..x.ax...aa..s.m..x.x.x.s.x.x.
# xmas..sx...x.....x.samxs.s.s.m.samxmasm.mm..s....m.......a.a...m...s.samx..mmms.mmm....x.x.a.xx.x........s..a..x.s......s.a.x........a....m.
# ......a.m.s.m.....m.s....s..a..s.....xa.x.xx.a....x......mm.s..samxaa..x...xx..a..x...m.s.m.m..m.m........amss..m.s.....xmas...xmas.msamx.as
# ......m..a.a.a...x.a.....xas..as....sssm.mssm.m..m.......x..xa..as.m.m.xmas..mss.m..xasamx.a.x..a.a.......xmaa..sa......x......xmasx...xmasa
# ......x...s.m.s.s.m.s.samx.m.m..a..aaaa.x.aa.a.xa..........s.mm..mxx..x..a....a.a...smm...s.s....s.s.s.s.samx.m.mas......s.........a.......m
# ...s..samx.axx.a.x.as.sas.s.xmas.mmmms.m.m.smsss........samxaxax..x......ss....s.m...xa...........a.a.a...x.x..x..mxx..x.xa....s....m...samx
# x.aaxa..m..mm.m.....sasama.......xxxxmasx.a.axx............smm.s.s..x.x.a..a...samx....s....x..x..xm.m.m...m.xmas.sxm.m.m.mm...xa....x.a....
# .m.mm..a..aa.x.a......m.mx........samx.samxm.m.............aa.x.a...mm.m....m..s.m....xmas...m.mm.m.x.x.x.a.x....a..aa.a...ax.m..m.sssms.s.s
# x.axa.s..ss...m.s....x.x.x..s.......xsx.x.x.a.............s..m.m.m..axx...samxasamx...........aa.aa..ssm.s...m..m...s.sxmas.sa....x.axa.a.a.
# .s.ss.a.x.....samx...s..samxa......m.sam...s................a.x.s.xss.m......m.s.xmas..ss......s..ss..aa......axx.........s.sa....x.mm.m.m..
# ......m..m...x..ss.s.a......m.....a..sama.........s....x...s.m..axa....a...sx.....a..x.a.a..x..x..xmas.mm......sxm..s..s.a..samx...mx.x.x...
# .s.samx..sas.m..a..a.m......xa...s...samxs....s...samxm...a.a...mmx.....s.a......ss.m..m..m.msm..s.s.m..xxxxxx..m.axxaaxm...samxxmasam.m....
# ..a..x..x.as.a.m...m.x.......ms......samx.x..as..a.xmas..m.s...xxaxmx....m..x.x..xaa...xsamxaaa...a.x.x..mmmmm..a..smmmx.........sxmasa....x
# x..mx.mm.m.m.sx..s.x.xmasxs..xa.x.....x.x..mm..amxm.sx..x.......msmsam..x..m...mm.sm....mxmasxsm.m.m.m.ma.aaaa..s...xaax...s.s.sa..s.s.s...m
# .m.mx.aax.a.xx..a.x.m.m.mxa.x.ms.m.s.m...s.xa..xmam.............saa.asa..ma.x.xaa..xx...ma..ma..xsamx.asas.sss..x...smss....aaam.....x.s...a
# ..a..s..s..s..mm.m.a...am.m.m..aa.a.a...a.a..s..sxmas........samxas.xmas.samx.sm.smm...as.sam....a.....sas.....m.m....a.a....mxm....m...a..s
# .s.s..........xaa.s...sas.xaa...sm.samxm...m........s.samx......samx..x...asamx.aaa...s...sx.....m.......m....a...a..m.s.m..xxx.x.samxmasm..
# .....samx......ss.....s.....s.....x...x.....x......................xmas..s......ss.........xmas..x........x..s.....sx.....x...samxs...xmasx.

# %% [markdown]
# ## --- Part Two ---
# The Elf looks quizzically at you. Did you misunderstand the assignment?
#
# Looking for the instructions, you flip over the word search to find that this isn't actually an `XMAS` puzzle; it's an X-MAS puzzle in which you're supposed to find two `MAS` in the shape of an `X`. One way to achieve that is like this:
#
# ```shell
# M.S
# .A.
# M.S
#
# ```
#
# Irrelevant characters have again been replaced with `.` in the above diagram. Within the `X`, each `MAS` can be written forwards or backwards.
#
# Here's the same example from before, but this time all of the `X-MAS`es have been kept instead:
#
# ```shell
# .M.S......
# ..A..MSMS.
# .M.S.MAA..
# ..A.ASMSM.
# .M.S.M....
# ..........
# S.S.S.S.S.
# .A.A.A.A..
# M.M.M.M.M.
# ..........
#
# ```
#
# In this example, an `X-MAS` appears `9` times.
#
# Flip the word search from the instructions back over to the word search side and try again. **How many times does an `X-MAS` appear?**

# %%
raw = '''
MMMSXXMASM
MSAMXMSMSA
AMXSXMAAMM
MSAMASMSMX
XMASAMXAMM
XXAMMXXAMA
SMSMSASXSS
SAXAMASAAA
MAMMMXMMMM
MXMXAXMASX
'''

data = np.array([list(line.strip()) for line in raw.strip().split('\n')])

def search_cross(array, word, x, y):
    '''searches for word in 2d array horizontally, vertically, and diagonally starting at x, y.
    replaces characters of found words to lowercase, and returns number of instances found.
    '''
    ys, xs = array.shape
    count = 0
    n = len(word)
    n2 = len(word) // 2
    word = word.lower()
    a2s = lambda a: ''.join(a).lower()
    s2a = lambda s: np.array(list(s))
    
    assert n % 2 != 0, 'Only for odd-length words'
    
    # diagonal
    i = np.diag_indices(n)
    j = tuple(i + np.array([y-n2, x-n2])[:, None])
    k = (j[0], j[1][::-1])
    if xs-n2 > x >= n2 and ys-n2 > y >= n2:
        if (a2s(array[j]) in (word, word[::-1])) and (a2s(array[k]) in (word, word[::-1])):
            count += 1
        
#        print(count, y, x, j, k, array[j], array[k])
    return count
    

total = 0
for y in range(data.shape[0]):
    for x in range(data.shape[1]):
        total += search_cross(data, 'mas', x, y)

print(total) 
data
# Out:
# 9
# array([['M', 'M', 'M', 'S', 'X', 'X', 'M', 'A', 'S', 'M'],
#        ['M', 'S', 'A', 'M', 'X', 'M', 'S', 'M', 'S', 'A'],
#        ['A', 'M', 'X', 'S', 'X', 'M', 'A', 'A', 'M', 'M'],
#        ['M', 'S', 'A', 'M', 'A', 'S', 'M', 'S', 'M', 'X'],
#        ['X', 'M', 'A', 'S', 'A', 'M', 'X', 'A', 'M', 'M'],
#        ['X', 'X', 'A', 'M', 'M', 'X', 'X', 'A', 'M', 'A'],
#        ['S', 'M', 'S', 'M', 'S', 'A', 'S', 'X', 'S', 'S'],
#        ['S', 'A', 'X', 'A', 'M', 'A', 'S', 'A', 'A', 'A'],
#        ['M', 'A', 'M', 'M', 'M', 'X', 'M', 'M', 'M', 'M'],
#        ['M', 'X', 'M', 'X', 'A', 'X', 'M', 'A', 'S', 'X']], dtype='<U1')

# %%
with open('day4.input') as f:
    data = np.array([list(line.strip()) for line in f.read().strip().split('\n')])
    
    
total = 0
for y in range(data.shape[0]):
    for x in range(data.shape[1]):
        total += search_cross(data, 'mas', x, y)

print(total)
# Out:
# 1978

# %% [markdown]
# ## Mistakes were made... What a dumb solution!
